# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
url = "https://api.yelp.com/v3/businesses/search?latitude=46.786588&longitude=-71.258231&radius=1000&sort_by=best_match&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": "BEARER HjsnA8Jnm6ABm9PbOlY5EThs1_lsVSzWHdLhiBAnLUGdq-LBe2knWNTjkpbH77RZCgRO0z1pqswOmlncC55ZB47u4SsIZQdzpWUz4_O9S2wz0TvciuNRtNSCy3t6ZHYx"
}

response = requests.get(url, headers=headers)
print(response.text)
# Out:
# {"businesses": [{"id": "ZuMk38cl-kS_mhKm4lAtUw", "alias": "montego-qu\u00e9bec-3", "name": "Montego", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/_JqFxssFcAcBgMlkIolJHw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/montego-qu%C3%A9bec-3?adjust_creative=aPwYBfhi4SeF37JyucLNOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=aPwYBfhi4SeF37JyucLNOA", "review_count": 16, "categories": [{"alias": "italian", "title": "Italian"}], "rating": 4.5, "coordinates": {"latitude": 46.7795463, "longitude": -71.2495237}, "transactions": [], "price": "$$$", "location": {"address1": "1460 Avenue Maguire", "address2": "", "address3": "", "city": "Quebec City", "zip_code": "G1T 1Z4", "country": "CA", "state": "QC", "display_address": ["1460 Avenue Maguire", "Quebec City, QC G1T 1Z4", "Canada"]}, "phone": "+14186887991", "display_phone": "+1 418-688-7991", "distance": 1037.551982419555}, {"id": "O9ILMKjZ3n3xbk2cbL_Plg", "alias": "la-girolle-qu\u00e9bec-2", "na
# ...

# %%
data =response.json()
df_1 = pd.DataFrame(data['businesses'])
#print(df_1.columns)

df1.head(2)
# Out:
#    review_count                                  categories  rating  \
# 0            16  [{'alias': 'italian', 'title': 'Italian'}]     4.5
# 1            11    [{'alias': 'french', 'title': 'French'}]     4.5
#
#                                          coordinates  \
# 0  {'latitude': 46.7795463, 'longitude': -71.2495...
# 1     {'latitude': 46.79437, 'longitude': -71.25556}
#
#                                             location     distance
# 0  {'address1': '1460 Avenue Maguire', 'address2'...  1037.551982
# 1  {'address1': '1384 Chemin Sainte-Foy', 'addres...   882.063380

# %%
cols_removed = ['id', 'alias', 'name', 'image_url', 'is_closed', 'url','transactions', 'price','phone', 'display_phone']

# %%
df1 = df_1.drop(cols_removed, axis = 1)
df1.head()
# Out:
#    review_count                                         categories  rating  \
# 0            16         [{'alias': 'italian', 'title': 'Italian'}]     4.5
# 1            11           [{'alias': 'french', 'title': 'French'}]     4.5
# 2            15             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 3            15  [{'alias': 'modern_european', 'title': 'Modern...     4.0
# 4             8  [{'alias': 'bagels', 'title': 'Bagels'}, {'ali...     4.5
#
#                                          coordinates  \
# 0  {'latitude': 46.7795463, 'longitude': -71.2495...
# 1     {'latitude': 46.79437, 'longitude': -71.25556}
# 2   {'latitude': 46.780923, 'longitude': -71.251234}
# 3     {'latitude': 46.78758, 'longitude': -71.26827}
# 4      {'latitude': 46.7804, 'longitude': -71.25052}
#
#                                             location     distance
# 0  {'address1': '1460 Avenue Maguire', 'address2'...  1037.551982
# ...

# %%
# poi['categories']
# x = pd.json_normalize(poi['categories'])
# x[0]

# pass
#cat_df = pd.json_normalize(x[0])
#cols = ['icon.prefix', 'icon.suffix']
#cat_df_0 = cat_df.drop(cols, axis=1)

"""
cat_df = pd.json_normalize(x[1])
cat_df_1 = cat_df.dropna()
cat_df_1 = cat_df_1.drop(cols, axis=1)


cat_df = pd.json_normalize(x[2])
cat_df_2 = cat_df.dropna()
cat_df_2 = cat_df_2.drop(cols, axis=1)
"""

df1['categories']
y = pd.json_normalize(df1['categories'])
#y[0]
#df1 = pd.json_normalize(y[0])
# df1.head()
#df1 = pd.DataFrame.from_records(df2)

# %%
y[0]
# Out:
# 0              {'alias': 'italian', 'title': 'Italian'}
# 1                {'alias': 'french', 'title': 'French'}
# 2                  {'alias': 'pizza', 'title': 'Pizza'}
# 3     {'alias': 'modern_european', 'title': 'Modern ...
# 4                {'alias': 'bagels', 'title': 'Bagels'}
# 5     {'alias': 'breakfast_brunch', 'title': 'Breakf...
# 6            {'alias': 'bakeries', 'title': 'Bakeries'}
# 7                    {'alias': 'pubs', 'title': 'Pubs'}
# 8        {'alias': 'gastropubs', 'title': 'Gastropubs'}
# 9     {'alias': 'tradamerican', 'title': 'American (...
# 10                 {'alias': 'parks', 'title': 'Parks'}
# 11    {'alias': 'breakfast_brunch', 'title': 'Breakf...
# 12            {'alias': 'beerbar', 'title': 'Beer Bar'}
# 13    {'alias': 'tapasmallplates', 'title': 'Tapas/S...
# 14             {'alias': 'burgers', 'title': 'Burgers'}
# 15               {'alias': 'french', 'title': 'French'}
# 16           {'alias': 'hotdogs', 'title': 'Fast Food'}
# ...

# %%
new_df = pd.json_normalize(y[0])

# %%
new_df
# Out:
#                alias                   title
# 0            italian                 Italian
# 1             french                  French
# 2              pizza                   Pizza
# 3    modern_european         Modern European
# 4             bagels                  Bagels
# 5   breakfast_brunch      Breakfast & Brunch
# 6           bakeries                Bakeries
# 7               pubs                    Pubs
# 8         gastropubs              Gastropubs
# 9       tradamerican  American (Traditional)
# 10             parks                   Parks
# 11  breakfast_brunch      Breakfast & Brunch
# 12           beerbar                Beer Bar
# 13   tapasmallplates      Tapas/Small Plates
# 14           burgers                 Burgers
# 15            french                  French
# 16           hotdogs               Fast Food
# 17       newcanadian          Canadian (New)
# 18           seafood                 Seafood
# 19          bakeries                Bakeries

# %%
new_df_1 = pd.json_normalize(y[1])
new_df_2 = pd.json_normalize(y[2])

# %%
new_df_1 = new_df_1.dropna()
new_df_1
# Out:
#               alias            title
# 3              pubs             Pubs
# 4             cafes            Cafes
# 5       newcanadian   Canadian (New)
# 6            french           French
# 7        brasseries       Brasseries
# 8              pubs             Pubs
# 9   modern_european  Modern European
# 11        creperies        Creperies
# 14       sandwiches       Sandwiches
# 16           diners           Diners
# 17       vegetarian       Vegetarian
# 18             bars             Bars

# %%
new_df_2 = new_df_1.dropna()
new_df_2
# Out:
#               alias            title
# 3              pubs             Pubs
# 4             cafes            Cafes
# 5       newcanadian   Canadian (New)
# 6            french           French
# 7        brasseries       Brasseries
# 8              pubs             Pubs
# 9   modern_european  Modern European
# 11        creperies        Creperies
# 14       sandwiches       Sandwiches
# 16           diners           Diners
# 17       vegetarian       Vegetarian
# 18             bars             Bars

# %%
merge_cols = [new_df, new_df_1, new_df_2]

# %%
categories = pd.concat(merge_cols, ignore_index = True)
categories
# Out:
#                alias                   title
# 0            italian                 Italian
# 1             french                  French
# 2              pizza                   Pizza
# 3    modern_european         Modern European
# 4             bagels                  Bagels
# 5   breakfast_brunch      Breakfast & Brunch
# 6           bakeries                Bakeries
# 7               pubs                    Pubs
# 8         gastropubs              Gastropubs
# 9       tradamerican  American (Traditional)
# 10             parks                   Parks
# 11  breakfast_brunch      Breakfast & Brunch
# 12           beerbar                Beer Bar
# 13   tapasmallplates      Tapas/Small Plates
# 14           burgers                 Burgers
# 15            french                  French
# 16           hotdogs               Fast Food
# 17       newcanadian          Canadian (New)
# 18           seafood                 Seafood
# 19          bakeries                Bakeries
# ...

# %%
# merge categories with df1
#df1 = df1.drop('categories', axis = 1)
#df1

# %%
# merge categories with df1  
# new_df, new_df_1, new_df_2]
final_df = pd.concat([df1, categories], axis = 1)

# %%
final_df
# Out:
#     review_count  rating                                           location  \
# 0           16.0     4.5  {'address1': '1460 Avenue Maguire', 'address2'...
# 1           11.0     4.5  {'address1': '1384 Chemin Sainte-Foy', 'addres...
# 2           15.0     4.5  {'address1': '1332 Avenue Maguire', 'address2'...
# 3           15.0     4.0  {'address1': '867 Avenue Myrand', 'address2': ...
# 4            8.0     4.5  {'address1': '1400 Avenue Maguire', 'address2'...
# 5            9.0     3.0  {'address1': '859 Avenue Myrand', 'address2': ...
# 6            9.0     4.5  {'address1': '1646 Chemin Saint-Louis', 'addre...
# 7           14.0     3.5  {'address1': '1380 Chemin Sainte-Foy', 'addres...
# 8            8.0     3.5  {'address1': '2325 Rue de l'Université', 'addr...
# 9            6.0     4.0  {'address1': '1308 Avenue Maguire', 'address2'...
# 10           6.0     5.0  {'address1': '1215 Grande Allée O', 'address2'...
# ...

# %%
final_df = final_df.dropna()

# %%
final_df = final_df.drop('alias', axis = 1)

# %%
normal = final_df['location']
normal
# Out:
# 0     {'address1': '1460 Avenue Maguire', 'address2'...
# 1     {'address1': '1384 Chemin Sainte-Foy', 'addres...
# 2     {'address1': '1332 Avenue Maguire', 'address2'...
# 3     {'address1': '867 Avenue Myrand', 'address2': ...
# 4     {'address1': '1400 Avenue Maguire', 'address2'...
# 5     {'address1': '859 Avenue Myrand', 'address2': ...
# 6     {'address1': '1646 Chemin Saint-Louis', 'addre...
# 7     {'address1': '1380 Chemin Sainte-Foy', 'addres...
# 8     {'address1': '2325 Rue de l'Université', 'addr...
# 9     {'address1': '1308 Avenue Maguire', 'address2'...
# 10    {'address1': '1215 Grande Allée O', 'address2'...
# 11    {'address1': '1292 Avenue Maguire', 'address2'...
# 12    {'address1': '814 Avenue Myrand', 'address2': ...
# 13    {'address1': '1297 Avenue Maguire', 'address2'...
# 14    {'address1': '1360 Avenue Maguire', 'address2'...
# 15    {'address1': '840 Avenue Myrand', 'address2': ...
# 16    {'address1': '1983 Rue de Bergerville', 'addre...
# ...

# %%
address = pd.json_normalize(normal)

# %%
address = pd.DataFrame(address)
add = address['address1']

# %%
# final_df = final_df.drop('location', axis = 1)
address
# Out:
#                     address1
# 0        1460 Avenue Maguire
# 1     1384 Chemin Sainte-Foy
# 2        1332 Avenue Maguire
# 3          867 Avenue Myrand
# 4        1400 Avenue Maguire
# 5          859 Avenue Myrand
# 6    1646 Chemin Saint-Louis
# 7     1380 Chemin Sainte-Foy
# 8   2325 Rue de l'Université
# 9        1308 Avenue Maguire
# 10       1215 Grande Allée O
# 11       1292 Avenue Maguire
# 12         814 Avenue Myrand
# 13       1297 Avenue Maguire
# 14       1360 Avenue Maguire
# 15         840 Avenue Myrand
# 16   1983 Rue de Bergerville
# 17       1314 Avenue Maguire
# 18   1626 Chemin Saint-Louis
# 19    1483 Chemin Sainte Foy

# %%
#final_df = pd.concat([final_df, address], axis = 1)
final_df = final_df.drop('address1', axis = 1)
final_df
# Out:
#     review_count  rating                                           location  \
# 0           16.0     4.5  {'address1': '1460 Avenue Maguire', 'address2'...
# 1           11.0     4.5  {'address1': '1384 Chemin Sainte-Foy', 'addres...
# 2           15.0     4.5  {'address1': '1332 Avenue Maguire', 'address2'...
# 3           15.0     4.0  {'address1': '867 Avenue Myrand', 'address2': ...
# 4            8.0     4.5  {'address1': '1400 Avenue Maguire', 'address2'...
# 5            9.0     3.0  {'address1': '859 Avenue Myrand', 'address2': ...
# 6            9.0     4.5  {'address1': '1646 Chemin Saint-Louis', 'addre...
# 7           14.0     3.5  {'address1': '1380 Chemin Sainte-Foy', 'addres...
# 8            8.0     3.5  {'address1': '2325 Rue de l'Université', 'addr...
# 9            6.0     4.0  {'address1': '1308 Avenue Maguire', 'address2'...
# 10           6.0     5.0  {'address1': '1215 Grande Allée O', 'address2'...
# ...

# %%
final_df = final_df.drop('location', axis = 1)
final_df
# Out:
#     review_count  rating     distance                   title
# 0           16.0     4.5  1037.551982                 Italian
# 1           11.0     4.5   882.063380                  French
# 2           15.0     4.5   825.002748                   Pizza
# 3           15.0     4.0   772.769412         Modern European
# 4            8.0     4.5   902.471446                  Bagels
# 5            9.0     3.0   754.079683      Breakfast & Brunch
# 6            9.0     4.5   943.503503                Bakeries
# 7           14.0     3.5   892.290007                    Pubs
# 8            8.0     3.5  1208.695584              Gastropubs
# 9            6.0     4.0   758.638619  American (Traditional)
# 10           6.0     5.0  1050.854627                   Parks
# 11           2.0     4.5   724.731087      Breakfast & Brunch
# 12           8.0     3.5   937.474484                Beer Bar
# 13           6.0     4.5   719.656067      Tapas/Small Plates
# ...

# %%
final_df = pd.concat([final_df, address], axis = 1)

# %%
final_df
# Out:
#     review_count  rating     distance                   title  \
# 0           16.0     4.5  1037.551982                 Italian
# 1           11.0     4.5   882.063380                  French
# 2           15.0     4.5   825.002748                   Pizza
# 3           15.0     4.0   772.769412         Modern European
# 4            8.0     4.5   902.471446                  Bagels
# 5            9.0     3.0   754.079683      Breakfast & Brunch
# 6            9.0     4.5   943.503503                Bakeries
# 7           14.0     3.5   892.290007                    Pubs
# 8            8.0     3.5  1208.695584              Gastropubs
# 9            6.0     4.0   758.638619  American (Traditional)
# 10           6.0     5.0  1050.854627                   Parks
# 11           2.0     4.5   724.731087      Breakfast & Brunch
# 12           8.0     3.5   937.474484                Beer Bar
# 13           6.0     4.5   719.656067      Tapas/Small Plates
# ...

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
final_df.to_csv('Yelp1.csv', index =False)

# %% [markdown]
# Put your parsed results into a DataFrame

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# Get the top 10 restaurants according to their rating
